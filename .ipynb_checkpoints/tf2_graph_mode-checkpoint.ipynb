# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, Input, BatchNormalization, Dropout, Activation, Flatten, Dense
import numpy as np

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %%
def main():
    # disctiminator
    input_dim = Input((512, 512, 3))
    
    inputs = Conv2D(filters=10, kernel_size=4, strides=2, padding='same', name='discriminator_conv_1')(input_dim)
    x = BatchNormalization(momentum=0.8)(inputs)
    x = Activation('relu')(x)
    
    x = Dropout(rate=0.4)(x)

    x = Conv2D(filters=20, kernel_size=4, strides=2, padding='same', name='discriminator_conv_2')(x)
    x = BatchNormalization(momentum=0.8)(x)
    x = Activation('relu')(x)
    x = Dropout(rate=0.4)(x)

    x = Conv2D(filters=30, kernel_size=4, strides=2, padding='same', name='discriminator_conv_3')(x)
    x = BatchNormalization(momentum=0.8)(x)
    x = Activation('relu')(x)
    x = Dropout(rate=0.4)(x)

    x = Conv2D(filters=40, kernel_size=4, strides=2, padding='same', name='discriminator_conv_4')(x)
    x = BatchNormalization(momentum=0.8)(x)
    x = Activation('relu')(x)
    x = Dropout(rate=0.4)(x)

    x = Conv2D(filters=50, kernel_size=4, strides=2, padding='same', name='discriminator_conv_5')(x)
    x = BatchNormalization(momentum=0.8)(x)
    x = Activation('relu')(x)
    x = Dropout(rate=0.4)(x)
    
    x = Conv2D(filters=60, kernel_size=4, strides=2, padding='same', name='discriminator_conv_6')(x)
    x = BatchNormalization(momentum=0.8)(x)
    x = Activation('relu')(x)
    x = Dropout(rate=0.4)(x)

    x = Flatten()(x)
    x = Dense(units=10)(x)
    outputs = BatchNormalization(momentum=0.8)(x)
    x = Activation('relu')(x)
    
    discriminator = Model(inputs=input_dim, outputs=outputs)
    discriminator.compile(loss='binary_crossentropy', metrics=['accuracy'])
    discriminator.summary()
    # generator
    input_dim = Input(100, 100)
    inputs = Dense(28 * 28 * 3)(input_dim)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout()(x)
    
    x = Reshape((28, 28, 3))(x)
    
    x = UpSampleing()(x)
    x = Conv2D()(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout()(x)
    
    x = UpSampleing()(x)
    x = Conv2D()(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout()(x)
    
    x = UpSampleing()(x)
    x = Conv2D()(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout()(x)
    
    x = UpSampleing()(x)
    x = Conv2D()(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    outputs = Dropout()(x)
    
    generator = Model(inputs, outputs)
    
    def calc_los(real, y_pred):
        y_pred = discriminator.predict(generator.predict(np.zeros(28 * 28 * 3)))
        return y_pred

    generator.compile(loss=calc_loss, metrics='accuracy')
    
    epochs = 10
    batch_size = 32
    for _ in epochs:
        for _ in 5:
            real = get_real_images(batch_size)
            fake = generator.predict(np.zeros(batch_size, 28, 28, 3))
            discriminator.fit(real, fake)
        generator.fit(np.zeros(100))
    
    print("done")

# %%
if __name__=='__main__':
    main()
# Out:
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_22 (InputLayer)        [(None, 512, 512, 3)]     0
# _________________________________________________________________
# discriminator_conv_1 (Conv2D (None, 256, 256, 10)      490
# _________________________________________________________________
# batch_normalization_90 (Batc (None, 256, 256, 10)      40
# _________________________________________________________________
# activation_85 (Activation)   (None, 256, 256, 10)      0
# _________________________________________________________________
# dropout_77 (Dropout)         (None, 256, 256, 10)      0
# _________________________________________________________________
# discriminator_conv_2 (Conv2D (None, 128, 128, 20)      3220
# _________________________________________________________________
# batch_normalization_91 (Batc (None, 128, 128, 20)      80
# ...
